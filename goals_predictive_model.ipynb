# %% [markdown]
# # Import Libraries and CSV File, Activate GPU

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from math import sqrt
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.inspection import permutation_importance
from sklearn.linear_model import LinearRegression, SGDRegressor, ElasticNet
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
#activating gpu... if able
physical_devices = tf.config.list_physical_devices("GPU")
try:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    print("GPU enabled")
except:
    print("CPU enabled")
    pass
# Out:
# GPU enabled

# %%
df = pd.read_csv(filepath_or_buffer='player_data.csv', index_col=0) #importing csv file into single dataframe, 'df'
df = df.drop('assists', axis=1) #dropping target variable to be used in assists predictive system
df_labels = df.pop('goals').astype(int) #creating dataframe for labels, 'df_labels', and removing target variable from df

# %% [markdown]
# # Creating Helpful Functions

# %%
def create_model(model_input, X_train, X_val, y_train, y_val):
    """function for creating sklearn models"""
    model = model_input
    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    r_squared = r2_score(y_val, y_pred)
    mae = mean_squared_error(y_val, y_pred)
    rmse = sqrt(mean_squared_error(y_val, y_pred))

    return model, r_squared, mae, rmse

def metrics(r2, mae, rmse):
    """function to see model evaluation metrics"""
    print('R2:', round(r2, 2) , 'MAE:', round(mae, 2), 'RMSE:', round(rmse, 2))

def perm_importance(feature_importance):
    """function to visualize permutation feature importance"""
    #sorting features by importance
    sorted_idx = feature_importance.importances_mean.argsort()
    
    #plotting feature importance figure
    plt.figure(figsize=(12, 6))
    plt.boxplot(feature_importance.importances[sorted_idx].T, vert=False, labels=X_val.columns[sorted_idx])
    plt.title("Permutation Importances (validation set)")
    plt.tight_layout()
    plt.show()

def coef_importance(feature_importance, X_train):
    """#function to visualize important features for each model"""
    features = X_train.columns
    #converting coefficients to absolute value for comparison of magnetude
    importances = abs(feature_importance)
    
    #sorting the features based on importance
    sorted_idx = np.argsort(importances)
    sorted_importances = importances[sorted_idx]
    sorted_feature_names = [features[i] for i in sorted_idx]
    
    #creating the plot
    plt.figure(figsize=(10, 6))
    plt.barh(sorted_feature_names, sorted_importances)
    plt.xlabel('Absolute Coefficient Value')
    plt.title('Feature Importances in Model')
    plt.tight_layout()
    plt.show()

def calculate_accuracy(predicted_arr, actual_arr, tolerance=5):
    """function to calculate the accuracy of predictions within a tolerance (default = 5 units) for numpy arrays"""
    if tolerance ==0:
        correct_predictions = np.sum(np.abs(predicted_arr - actual_arr) == tolerance) #calculate the number of correct predictions
        accuracy = round((correct_predictions / predicted_arr.shape[0]) * 100, 2) #calculate accuracy
    else:
        correct_predictions = np.sum(np.abs(predicted_arr - actual_arr) <= tolerance) #calculate the number of correct predictions
        accuracy = round((correct_predictions / predicted_arr.shape[0]) * 100, 2) #calculate accuracy
    
    return accuracy

def model_prediction(model, X_test, y_test):
    """function to generate model predictions"""
    y_pred = model.predict(X_test)
    y_pred = np.squeeze(np.round(y_pred, decimals=0).astype(int))
    y_actual = y_test.to_numpy(dtype=int)
        
    return y_pred, y_actual

# %% [markdown]
# ### Train, Validation, Test Splitting

# %%
#splitting data to be 70% training, 15% validation, 15% test
X_train, X_tmp, y_train, y_tmp = train_test_split(df, df_labels, test_size=0.3, random_state=42) #split training data from temporary data (validation and test)
X_val, X_test, y_val, y_test = train_test_split(X_tmp, y_tmp, test_size=0.5, random_state=42) #split temporary data into validation and test data

# %%
col_list = ['playerId', 'name']

X_train = X_train.drop(col_list, axis=1)
X_val = X_val.drop(col_list, axis=1)
X_test = X_test.drop(col_list, axis=1)

# %% [markdown]
# # Support Vector Regressor

# %%
svr_model, svr_r2, svr_mae, svr_rmse = create_model(SVR(), X_train, X_val, y_train, y_val)
svr_importance = permutation_importance(svr_model, X_val, y_val)
metrics(svr_r2, svr_mae, svr_rmse)
# Out:
# R2: 0.75 MAE: 20.75 RMSE: 4.56

# %%
y_pred_svr, y_actual_svr = model_prediction(svr_model, X_test, y_test)

# %%
accuracy = calculate_accuracy(y_pred_svr, y_actual_svr)
print(accuracy)
# Out:
# 83.66

# %%
perm_importance(svr_importance)

# %% [markdown]
# # Linear Regression

# %%
linear_model, linear_r2, linear_mae, linear_rmse = create_model(LinearRegression(), X_train, X_val, y_train, y_val)
linear_importance = linear_model.coef_
metrics(linear_r2, linear_mae, linear_rmse)
# Out:
# R2: 0.95 MAE: 4.05 RMSE: 2.01

# %%
y_pred_linear, y_actual_linear = model_prediction(linear_model, X_test, y_test)

# %%
accuracy = calculate_accuracy(y_pred_linear, y_actual_linear)
print(accuracy)
# Out:
# 97.07

# %%
coef_importance(linear_importance, X_train)

# %% [markdown]
# # Elastic Net

# %%
elasticNet_model, en_r2, en_mae, en_rmse = create_model(ElasticNet(), X_train, X_val, y_train, y_val)
en_importance = elasticNet_model.coef_
metrics(en_r2, en_mae, en_rmse)
# Out:
# R2: 0.88 MAE: 10.13 RMSE: 3.18

# %%
y_pred_en, y_actual_en = model_prediction(elasticNet_model, X_test, y_test)

# %%
accuracy = calculate_accuracy(y_pred_en, y_actual_en)
print(accuracy)
# Out:
# 90.37

# %%
coef_importance(en_importance, X_train)

# %% [markdown]
# # Gradient Boosting

# %%
gb_model, gb_r2, gb_mae, gb_rmse = create_model(GradientBoostingRegressor(), X_train, X_val, y_train, y_val)
gb_importance = gb_model.feature_importances_
metrics(gb_r2, gb_mae, gb_rmse)
# Out:
# R2: 0.99 MAE: 1.22 RMSE: 1.1

# %%
y_pred_gb, y_actual_gb = model_prediction(gb_model, X_test, y_test)

# %%
accuracy = calculate_accuracy(y_pred_gb, y_actual_gb)
print(accuracy)
# Out:
# 99.88

# %%
coef_importance(gb_importance, X_train)

# %% [markdown]
# # Random Forest

# %%
rf_model, rf_r2, rf_mae, rf_rmse = create_model(RandomForestRegressor(), X_train, X_val, y_train, y_val)
rf_importance = rf_model.feature_importances_
metrics(rf_r2, rf_mae, rf_rmse)
# Out:
# R2: 0.99 MAE: 1.13 RMSE: 1.06

# %%
y_pred_rf, y_actual_rf = model_prediction(rf_model, X_test, y_test)

# %%
accuracy = calculate_accuracy(y_pred_rf, y_actual_rf)
print(accuracy)
# Out:
# 99.51

# %%
coef_importance(rf_importance, X_train)

# %% [markdown]
# # Neural Network

# %%
class RSquared(tf.keras.metrics.Metric):
    def __init__(self, name='r_squared', **kwargs):
        super(RSquared, self).__init__(name=name, **kwargs)
        self.sse = tf.keras.metrics.Sum()  #sum of squared errors
        self.sst = tf.keras.metrics.Sum()  #total sum of squares

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        error = y_true - y_pred
        squared_error = tf.square(error)
        self.sse.update_state(squared_error)

        mean_true = tf.reduce_mean(y_true)
        total_error = y_true - mean_true
        squared_total_error = tf.square(total_error)
        self.sst.update_state(squared_total_error)

    def result(self):
        return 1 - (self.sse.result() / self.sst.result())

    def reset_states(self):
        self.sse.reset_states()
        self.sst.reset_states()

# %%
shape = X_train.shape[1]

nn_model = tf.keras.models.Sequential()
nn_model.add(layers.Dense(64, input_dim=shape, kernel_initializer='he_normal'))
nn_model.add(layers.BatchNormalization())
nn_model.add(layers.Activation('relu'))

nn_model.add(layers.Dense(64, kernel_initializer='he_normal'))
nn_model.add(layers.BatchNormalization())
nn_model.add(layers.Activation('relu'))

nn_model.add(layers.Dense(128, kernel_initializer='he_normal'))
nn_model.add(layers.BatchNormalization())
nn_model.add(layers.Activation('relu'))
nn_model.add(layers.Dropout(0.125))

nn_model.add(layers.Dense(64, kernel_initializer='he_normal'))
nn_model.add(layers.BatchNormalization())
nn_model.add(layers.Activation('relu'))

nn_model.add(layers.Dense(32, kernel_initializer='he_normal'))
nn_model.add(layers.BatchNormalization())
nn_model.add(layers.Activation('relu'))

nn_model.add(layers.Dense(16, kernel_initializer='he_normal'))
nn_model.add(layers.BatchNormalization())
nn_model.add(layers.Activation('relu'))

nn_model.add(layers.Dense(8, kernel_initializer='he_normal'))
nn_model.add(layers.BatchNormalization())
nn_model.add(layers.Activation('relu'))

nn_model.add(layers.Dense(1, activation='linear'))

nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                2432
#
#  batch_normalization (BatchN  (None, 64)               256
#  ormalization)
#
#  activation (Activation)     (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  batch_normalization_1 (Batc  (None, 64)               256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 64)                0
#
#  dense_2 (Dense)             (None, 128)               8320
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 128)               0
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  batch_normalization_4 (Batc  (None, 32)               128
#  hNormalization)
#
#  activation_4 (Activation)   (None, 32)                0
#
#  dense_5 (Dense)             (None, 16)                528
#
#  batch_normalization_5 (Batc  (None, 16)               64
#  hNormalization)
#
#  activation_5 (Activation)   (None, 16)                0
#
#  dense_6 (Dense)             (None, 8)                 136
#
#  batch_normalization_6 (Batc  (None, 8)                32
#  hNormalization)
#
#  activation_6 (Activation)   (None, 8)                 0
#
#  dense_7 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 27,425
# Trainable params: 26,673
# Non-trainable params: 752
# _________________________________________________________________

# %%
nn_model.compile(loss='mae', optimizer='adam', metrics=[RSquared()])

# %%
#implementing early stoping to avoid overfitting and also just to prevent furhter uneccessary epochs.
es = tf.keras.callbacks.EarlyStopping('val_loss', patience=25, mode='min')

hist=nn_model.fit(X_train, y_train, batch_size=128, validation_data=(X_val, y_val),
              epochs=150, verbose=1, callbacks=[es])
# Out:
# Epoch 1/150
# 30/30 [==============================] - 3s 21ms/step - loss: 10.2057 - r_squared: -1.2558 - val_loss: 9.6760 - val_r_squared: -1.1633
# Epoch 2/150
# 30/30 [==============================] - 0s 12ms/step - loss: 9.8723 - r_squared: -1.1540 - val_loss: 9.1395 - val_r_squared: -1.0014
# Epoch 3/150
# 30/30 [==============================] - 0s 11ms/step - loss: 9.5830 - r_squared: -1.0623 - val_loss: 9.4822 - val_r_squared: -1.0938
# Epoch 4/150
# 30/30 [==============================] - 0s 12ms/step - loss: 9.3409 - r_squared: -0.9771 - val_loss: 9.4459 - val_r_squared: -1.0967
# Epoch 5/150
# 30/30 [==============================] - 0s 12ms/step - loss: 9.1131 - r_squared: -0.9060 - val_loss: 9.1446 - val_r_squared: -0.9782
# Epoch 6/150
# 30/30 [==============================] - 0s 12ms/step - loss: 8.8874 - r_squared: -0.8239 - val_loss: 8.8778 - val_r_squared: -0.9086
# Epoch 7/150
# 30/30 [==============================] - 0s 12ms/step - loss: 8.6660 - r_squared: -0.7683 - val_loss: 8.5173 - val_r_squared: -0.8076
# Epoch 8/150
# 30/30 [==============================] - 0s 11ms/step - loss: 8.4236 - r_squared: -0.6950 - val_loss: 8.1276 - val_r_squared: -0.6764
# Epoch 9/150
# 30/30 [==============================] - 0s 12ms/step - loss: 8.1439 - r_squared: -0.5930 - val_loss: 7.5719 - val_r_squared: -0.4879
# Epoch 10/150
# 30/30 [==============================] - 0s 12ms/step - loss: 7.8461 - r_squared: -0.4950 - val_loss: 7.2472 - val_r_squared: -0.3837
# Epoch 11/150
# 30/30 [==============================] - 0s 12ms/step - loss: 7.5470 - r_squared: -0.4180 - val_loss: 7.1621 - val_r_squared: -0.3328
# Epoch 12/150
# 30/30 [==============================] - 0s 12ms/step - loss: 7.2529 - r_squared: -0.3298 - val_loss: 7.4606 - val_r_squared: -0.3524
# Epoch 13/150
# 30/30 [==============================] - 0s 12ms/step - loss: 6.9391 - r_squared: -0.2429 - val_loss: 6.9982 - val_r_squared: -0.2409
# Epoch 14/150
# 30/30 [==============================] - 0s 12ms/step - loss: 6.6250 - r_squared: -0.1504 - val_loss: 6.3002 - val_r_squared: -0.0782
# Epoch 15/150
# 30/30 [==============================] - 0s 12ms/step - loss: 6.2944 - r_squared: -0.0650 - val_loss: 5.8191 - val_r_squared: 0.0361
# Epoch 16/150
# 30/30 [==============================] - 0s 16ms/step - loss: 5.9735 - r_squared: 0.0278 - val_loss: 5.7257 - val_r_squared: 0.0838
# Epoch 17/150
# 30/30 [==============================] - 0s 12ms/step - loss: 5.6432 - r_squared: 0.1248 - val_loss: 5.1695 - val_r_squared: 0.2406
# Epoch 18/150
# 30/30 [==============================] - 0s 12ms/step - loss: 5.3385 - r_squared: 0.2093 - val_loss: 5.4072 - val_r_squared: 0.2469
# Epoch 19/150
# 30/30 [==============================] - 0s 12ms/step - loss: 5.0125 - r_squared: 0.2928 - val_loss: 5.1518 - val_r_squared: 0.3088
# Epoch 20/150
# 30/30 [==============================] - 0s 12ms/step - loss: 4.7111 - r_squared: 0.3811 - val_loss: 5.0460 - val_r_squared: 0.3922
# Epoch 21/150
# 30/30 [==============================] - 0s 12ms/step - loss: 4.4277 - r_squared: 0.4389 - val_loss: 4.7472 - val_r_squared: 0.4151
# Epoch 22/150
# 30/30 [==============================] - 0s 12ms/step - loss: 4.1268 - r_squared: 0.5211 - val_loss: 3.7831 - val_r_squared: 0.5883
# Epoch 23/150
# 30/30 [==============================] - 0s 12ms/step - loss: 3.8793 - r_squared: 0.5850 - val_loss: 3.3127 - val_r_squared: 0.6862
# Epoch 24/150
# 30/30 [==============================] - 0s 12ms/step - loss: 3.6161 - r_squared: 0.6355 - val_loss: 3.2219 - val_r_squared: 0.7405
# Epoch 25/150
# 30/30 [==============================] - 0s 12ms/step - loss: 3.3710 - r_squared: 0.6898 - val_loss: 3.1654 - val_r_squared: 0.7403
# Epoch 26/150
# 30/30 [==============================] - 0s 12ms/step - loss: 3.1745 - r_squared: 0.7241 - val_loss: 2.9042 - val_r_squared: 0.7853
# Epoch 27/150
# 30/30 [==============================] - 0s 12ms/step - loss: 3.0261 - r_squared: 0.7613 - val_loss: 3.3019 - val_r_squared: 0.7329
# Epoch 28/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.8527 - r_squared: 0.7935 - val_loss: 2.6800 - val_r_squared: 0.8313
# Epoch 29/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.8151 - r_squared: 0.7953 - val_loss: 2.9271 - val_r_squared: 0.8098
# Epoch 30/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.6762 - r_squared: 0.8226 - val_loss: 2.8564 - val_r_squared: 0.8146
# Epoch 31/150
# 30/30 [==============================] - 0s 13ms/step - loss: 2.6551 - r_squared: 0.8201 - val_loss: 2.8297 - val_r_squared: 0.8137
# Epoch 32/150
# 30/30 [==============================] - 0s 13ms/step - loss: 2.5521 - r_squared: 0.8399 - val_loss: 2.6097 - val_r_squared: 0.8433
# Epoch 33/150
# 30/30 [==============================] - 0s 13ms/step - loss: 2.4935 - r_squared: 0.8498 - val_loss: 3.5569 - val_r_squared: 0.6592
# Epoch 34/150
# 30/30 [==============================] - 0s 14ms/step - loss: 2.4611 - r_squared: 0.8521 - val_loss: 2.7030 - val_r_squared: 0.8205
# Epoch 35/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.4229 - r_squared: 0.8582 - val_loss: 2.5565 - val_r_squared: 0.8405
# Epoch 36/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.5151 - r_squared: 0.8473 - val_loss: 2.5115 - val_r_squared: 0.8453
# Epoch 37/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.4448 - r_squared: 0.8581 - val_loss: 2.5230 - val_r_squared: 0.8515
# Epoch 38/150
# 30/30 [==============================] - 0s 13ms/step - loss: 2.4107 - r_squared: 0.8603 - val_loss: 2.5226 - val_r_squared: 0.8524
# Epoch 39/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.4682 - r_squared: 0.8545 - val_loss: 2.4761 - val_r_squared: 0.8524
# Epoch 40/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.5142 - r_squared: 0.8482 - val_loss: 2.5618 - val_r_squared: 0.8394
# Epoch 41/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.4168 - r_squared: 0.8614 - val_loss: 2.7314 - val_r_squared: 0.8097
# Epoch 42/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.3902 - r_squared: 0.8630 - val_loss: 2.3663 - val_r_squared: 0.8682
# Epoch 43/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.3784 - r_squared: 0.8646 - val_loss: 2.3554 - val_r_squared: 0.8685
# Epoch 44/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.3675 - r_squared: 0.8688 - val_loss: 2.6595 - val_r_squared: 0.8135
# Epoch 45/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.3921 - r_squared: 0.8654 - val_loss: 2.7560 - val_r_squared: 0.8110
# Epoch 46/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.3649 - r_squared: 0.8693 - val_loss: 2.4590 - val_r_squared: 0.8530
# Epoch 47/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.3290 - r_squared: 0.8723 - val_loss: 2.4850 - val_r_squared: 0.8445
# Epoch 48/150
# 30/30 [==============================] - 0s 13ms/step - loss: 2.3902 - r_squared: 0.8637 - val_loss: 2.6339 - val_r_squared: 0.8467
# Epoch 49/150
# 30/30 [==============================] - 0s 13ms/step - loss: 2.3550 - r_squared: 0.8674 - val_loss: 2.5575 - val_r_squared: 0.8284
# Epoch 50/150
# 30/30 [==============================] - 0s 13ms/step - loss: 2.3735 - r_squared: 0.8646 - val_loss: 2.4776 - val_r_squared: 0.8454
# Epoch 51/150
# 30/30 [==============================] - 0s 15ms/step - loss: 2.3363 - r_squared: 0.8712 - val_loss: 2.4585 - val_r_squared: 0.8526
# Epoch 52/150
# 30/30 [==============================] - 0s 14ms/step - loss: 2.2804 - r_squared: 0.8746 - val_loss: 2.3680 - val_r_squared: 0.8669
# Epoch 53/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.3426 - r_squared: 0.8682 - val_loss: 2.4491 - val_r_squared: 0.8576
# Epoch 54/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.3075 - r_squared: 0.8713 - val_loss: 2.4742 - val_r_squared: 0.8477
# Epoch 55/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.3253 - r_squared: 0.8672 - val_loss: 2.5610 - val_r_squared: 0.8377
# Epoch 56/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2941 - r_squared: 0.8742 - val_loss: 2.3869 - val_r_squared: 0.8662
# Epoch 57/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2632 - r_squared: 0.8787 - val_loss: 2.4725 - val_r_squared: 0.8425
# Epoch 58/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2852 - r_squared: 0.8733 - val_loss: 2.3738 - val_r_squared: 0.8627
# Epoch 59/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2598 - r_squared: 0.8781 - val_loss: 2.4946 - val_r_squared: 0.8491
# Epoch 60/150
# 30/30 [==============================] - 0s 13ms/step - loss: 2.2717 - r_squared: 0.8762 - val_loss: 2.9375 - val_r_squared: 0.7696
# Epoch 61/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2658 - r_squared: 0.8777 - val_loss: 2.3409 - val_r_squared: 0.8648
# Epoch 62/150
# 30/30 [==============================] - 0s 15ms/step - loss: 2.2835 - r_squared: 0.8776 - val_loss: 2.5954 - val_r_squared: 0.8332
# Epoch 63/150
# 30/30 [==============================] - 0s 13ms/step - loss: 2.2644 - r_squared: 0.8764 - val_loss: 2.3862 - val_r_squared: 0.8678
# Epoch 64/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2960 - r_squared: 0.8710 - val_loss: 2.5567 - val_r_squared: 0.8327
# Epoch 65/150
# 30/30 [==============================] - 0s 11ms/step - loss: 2.2649 - r_squared: 0.8769 - val_loss: 2.3875 - val_r_squared: 0.8623
# Epoch 66/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2538 - r_squared: 0.8768 - val_loss: 2.4172 - val_r_squared: 0.8586
# Epoch 67/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2237 - r_squared: 0.8790 - val_loss: 2.6285 - val_r_squared: 0.8237
# Epoch 68/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2715 - r_squared: 0.8760 - val_loss: 2.5235 - val_r_squared: 0.8383
# Epoch 69/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2173 - r_squared: 0.8814 - val_loss: 2.3984 - val_r_squared: 0.8576
# Epoch 70/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2073 - r_squared: 0.8834 - val_loss: 2.3614 - val_r_squared: 0.8663
# Epoch 71/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2257 - r_squared: 0.8785 - val_loss: 2.3796 - val_r_squared: 0.8674
# Epoch 72/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.1977 - r_squared: 0.8809 - val_loss: 3.0285 - val_r_squared: 0.7744
# Epoch 73/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2894 - r_squared: 0.8706 - val_loss: 2.3904 - val_r_squared: 0.8639
# Epoch 74/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2218 - r_squared: 0.8796 - val_loss: 2.2971 - val_r_squared: 0.8731
# Epoch 75/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2359 - r_squared: 0.8814 - val_loss: 2.6069 - val_r_squared: 0.8132
# Epoch 76/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2702 - r_squared: 0.8750 - val_loss: 2.4693 - val_r_squared: 0.8526
# Epoch 77/150
# 30/30 [==============================] - 0s 13ms/step - loss: 2.2262 - r_squared: 0.8798 - val_loss: 2.4436 - val_r_squared: 0.8513
# Epoch 78/150
# 30/30 [==============================] - 0s 15ms/step - loss: 2.2209 - r_squared: 0.8811 - val_loss: 2.5597 - val_r_squared: 0.8338
# Epoch 79/150
# 30/30 [==============================] - 0s 14ms/step - loss: 2.2084 - r_squared: 0.8818 - val_loss: 2.4735 - val_r_squared: 0.8509
# Epoch 80/150
# 30/30 [==============================] - 0s 13ms/step - loss: 2.2431 - r_squared: 0.8776 - val_loss: 2.5073 - val_r_squared: 0.8547
# Epoch 81/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.1247 - r_squared: 0.8928 - val_loss: 2.5127 - val_r_squared: 0.8312
# Epoch 82/150
# 30/30 [==============================] - 0s 14ms/step - loss: 2.1452 - r_squared: 0.8914 - val_loss: 2.4932 - val_r_squared: 0.8439
# Epoch 83/150
# 30/30 [==============================] - 0s 13ms/step - loss: 2.1713 - r_squared: 0.8844 - val_loss: 2.3372 - val_r_squared: 0.8701
# Epoch 84/150
# 30/30 [==============================] - 0s 14ms/step - loss: 2.1318 - r_squared: 0.8897 - val_loss: 2.5989 - val_r_squared: 0.8374
# Epoch 85/150
# 30/30 [==============================] - 0s 14ms/step - loss: 2.2454 - r_squared: 0.8767 - val_loss: 2.6218 - val_r_squared: 0.8312
# Epoch 86/150
# 30/30 [==============================] - 0s 15ms/step - loss: 2.2132 - r_squared: 0.8800 - val_loss: 2.6359 - val_r_squared: 0.8400
# Epoch 87/150
# 30/30 [==============================] - 0s 14ms/step - loss: 2.1676 - r_squared: 0.8855 - val_loss: 2.4399 - val_r_squared: 0.8558
# Epoch 88/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.1101 - r_squared: 0.8918 - val_loss: 2.3140 - val_r_squared: 0.8724
# Epoch 89/150
# 30/30 [==============================] - 0s 14ms/step - loss: 2.2235 - r_squared: 0.8801 - val_loss: 2.4833 - val_r_squared: 0.8560
# Epoch 90/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.2387 - r_squared: 0.8793 - val_loss: 2.7873 - val_r_squared: 0.7882
# Epoch 91/150
# 30/30 [==============================] - 0s 13ms/step - loss: 2.1626 - r_squared: 0.8905 - val_loss: 2.3963 - val_r_squared: 0.8643
# Epoch 92/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.1287 - r_squared: 0.8893 - val_loss: 2.4329 - val_r_squared: 0.8542
# Epoch 93/150
# 30/30 [==============================] - 0s 13ms/step - loss: 2.0977 - r_squared: 0.8919 - val_loss: 2.4690 - val_r_squared: 0.8537
# Epoch 94/150
# 30/30 [==============================] - 0s 14ms/step - loss: 2.1473 - r_squared: 0.8854 - val_loss: 2.4198 - val_r_squared: 0.8596
# Epoch 95/150
# 30/30 [==============================] - 0s 15ms/step - loss: 2.1249 - r_squared: 0.8920 - val_loss: 2.4355 - val_r_squared: 0.8573
# Epoch 96/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.1433 - r_squared: 0.8856 - val_loss: 2.3408 - val_r_squared: 0.8661
# Epoch 97/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.1431 - r_squared: 0.8889 - val_loss: 2.6036 - val_r_squared: 0.8299
# Epoch 98/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.1351 - r_squared: 0.8908 - val_loss: 2.5561 - val_r_squared: 0.8505
# Epoch 99/150
# 30/30 [==============================] - 0s 12ms/step - loss: 2.1985 - r_squared: 0.8840 - val_loss: 2.6282 - val_r_squared: 0.8327

# %%
plt.plot(hist.history['r_squared'], label='r2')
plt.plot(hist.history['val_r_squared'], label='val_r2')
plt.ylim((0, 1))
plt.legend()

# %%
y_pred_nn, y_actual_nn = model_prediction(nn_model, X_test, y_test)
# Out:
# 26/26 [==============================] - 0s 3ms/step

# %%
accuracy = calculate_accuracy(y_pred_nn, y_actual_nn)
print(accuracy)
# Out:
# 88.54

# %% [markdown]
# # Testing Accuracy with Different Tolerances

# %% [markdown]
# ### Tolerance = 3

# %%
accuracy = calculate_accuracy(y_pred_svr, y_actual_svr, tolerance=3)
print('svr:', accuracy)
# Out:
# svr: 67.44

# %%
accuracy = calculate_accuracy(y_pred_linear, y_actual_linear, tolerance=3)
print('linear:', accuracy)
# Out:
# linear: 91.71

# %%
accuracy = calculate_accuracy(y_pred_en, y_actual_en, tolerance=3)
print('elasticNet:', accuracy)
# Out:
# elasticNet: 77.2

# %%
accuracy = calculate_accuracy(y_pred_gb, y_actual_gb, tolerance=3)
print('gradient boosting:', accuracy)
# Out:
# gradient boosting: 98.9

# %%
accuracy = calculate_accuracy(y_pred_rf, y_actual_rf, tolerance=3)
print('random forest:', accuracy)
# Out:
# random forest: 98.78

# %%
accuracy = calculate_accuracy(y_pred_nn, y_actual_nn, tolerance=3)
print('neural network:', accuracy)
# Out:
# neural network: 74.39

# %% [markdown]
# ### Tolerance = 1

# %%
accuracy = calculate_accuracy(y_pred_svr, y_actual_svr, tolerance=1)
print('svr:', accuracy)
# Out:
# svr: 36.1

# %%
accuracy = calculate_accuracy(y_pred_linear, y_actual_linear, tolerance=1)
print('linear:', accuracy)
# Out:
# linear: 65.0

# %%
accuracy = calculate_accuracy(y_pred_en, y_actual_en, tolerance=1)
print('elasticNet:', accuracy)
# Out:
# elasticNet: 44.27

# %%
accuracy = calculate_accuracy(y_pred_gb, y_actual_gb, tolerance=1)
print('gradient boosting:', accuracy)
# Out:
# gradient boosting: 88.41

# %%
accuracy = calculate_accuracy(y_pred_rf, y_actual_rf, tolerance=1)
print('random forest:', accuracy)
# Out:
# random forest: 92.44

# %%
accuracy = calculate_accuracy(y_pred_nn, y_actual_nn, tolerance=1)
print('neural network:', accuracy)
# Out:
# neural network: 40.85

# %% [markdown]
# # Prediction on Whole Dataset

# %%
df_ids = df[col_list] #col_list is a list containing the playerId and name column names
df = df.drop(col_list, axis=1)

# %%
y_pred, y_actual = model_prediction(rf_model, df, df_labels)
accuracy = calculate_accuracy(y_pred, y_actual)
print(accuracy)
# Out:
# 99.84

# %%
accuracy = calculate_accuracy(y_pred, y_actual, 3)
print(accuracy)
# Out:
# 99.56

# %%
accuracy = calculate_accuracy(y_pred, y_actual, 1)
print(accuracy)
# Out:
# 97.36
